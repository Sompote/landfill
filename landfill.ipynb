# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import os
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error


class ResNetEncoder(nn.Module):
    def __init__(self, num_channels=1):
        super(ResNetEncoder, self).__init__()

        # Define ResNet layers (modify based on your specific ResNet architecture)
        self.resnet = nn.Sequential(
            nn.Conv2d(num_channels, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            # Add more ResNet layers here...
        )

    def forward(self, x):
        x = self.resnet(x)
        return x

class FNNReducer(nn.Module):
    def __init__(self, input_size):  # Pass the input size here
        super(FNNReducer, self).__init__()

        # Define fully connected layers
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=input_size, out_features=1024),  # Use input_size
            nn.ReLU(inplace=True),
            nn.Linear(1024, 20 * 20),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.fc(x)
        return x

class CNNExpander(nn.Module):
    def __init__(self):
        super(CNNExpander, self).__init__()

        # Define convolutional layers
        self.conv_transpose = nn.ConvTranspose2d(
        in_channels=1,
        out_channels=1,
        kernel_size=(24, 24),
        stride=(24, 24),
        padding=(0, 0)
    )


    def forward(self, x):
        x = self.conv_transpose(x)
        return x

class UpsampleNet(nn.Module):
    def __init__(self):
        super(UpsampleNet, self).__init__()
        # Define the first ConvTranspose2d layer
        self.conv_transpose1 = nn.ConvTranspose2d(
            in_channels=1,
            out_channels=1,
            kernel_size=3,
            stride=2,
            padding=1,
            output_padding=1
        )
        # Define the second ConvTranspose2d layer
        self.conv_transpose2 = nn.ConvTranspose2d(
            in_channels=1,
            out_channels=1,
            kernel_size=3,
            stride=2,
            padding=1,
            output_padding=1
        )
        # ... Add more layers as needed ...
        # Define the final ConvTranspose2d layer to reach the desired size
        self.conv_transpose_final = nn.ConvTranspose2d(
            in_channels=1,
            out_channels=1,
            kernel_size=3,
            stride=24,
            padding=1
        )

    def forward(self, x):
        # Apply the first ConvTranspose2d layer
        x = self.conv_transpose1(x)
        # Apply the second ConvTranspose2d layer
        x = self.conv_transpose2(x)
        # ... Apply additional layers as needed ...
        # Apply the final ConvTranspose2d layer
        x = self.conv_transpose_final(x)
        return x

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.resnet_encoder = ResNetEncoder()
        # Calculate the input size for FNNReducer after a forward pass through ResNetEncoder
        dummy_input = torch.randn(1, 1, 480, 480)
        dummy_output = self.resnet_encoder(dummy_input)
        # Fix: Calculate input size considering the concatenation of two ResNet outputs
        input_size = dummy_output.shape[1] * 2 * dummy_output.shape[2] * dummy_output.shape[3]
        self.fnn_reducer = FNNReducer(input_size)  # Pass the calculated input size
        self.cnn_expander = CNNExpander()
        self.UpsampleNet= UpsampleNet()

    def forward(self, x1, x2):
        # ResNet encoding
        x1 = self.resnet_encoder(x1)
        x2 = self.resnet_encoder(x2)

        # Concatenate features
        x = torch.cat((x1, x2), dim=1)  # Concatenation doubles the number of channels

        # FNN reduction
        x = self.fnn_reducer(x)

        # Reshape to [batch_size, 1, 20, 20]
        x = x.view(-1, 1, 20, 20)
        #print(x.shape)
        # CNN expansion
        x = self.cnn_expander(x)

        return x

class ImageDataset(Dataset):
    def __init__(self, input1_folder, input2_folder, output_folder, transform=None):
        self.input1_folder = input1_folder
        self.input2_folder = input2_folder
        self.output_folder = output_folder
        self.input1_filenames = sorted(os.listdir(input1_folder))
        self.input2_filenames = sorted(os.listdir(input2_folder))
        self.output_filenames = sorted(os.listdir(output_folder))
        self.transform = transform

    def __len__(self):
        return len(self.input1_filenames)

    def __getitem__(self, idx):
        input1_path = os.path.join(self.input1_folder, self.input1_filenames[idx])
        input2_path = os.path.join(self.input2_folder, self.input2_filenames[idx])
        output_path = os.path.join(self.output_folder, self.output_filenames[idx])

        input1 = Image.open(input1_path).convert('L')
        input2 = Image.open(input2_path).convert('L')
        output = Image.open(output_path).convert('L')

        if self.transform:
            input1 = self.transform(input1)
            input2 = self.transform(input2)
            output = self.transform(output)

        return input1, input2, output

def train(model, train_dataloader, test_dataloader, optimizer, criterion, epochs):
# CUDA Usage:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = Model().to(device)  # Move the model to the GPU

    for epoch in range(epochs):
        running_loss = 0.0
        model.train()  # Set the model to training mode
        for i, data in enumerate(train_dataloader):
            input1, input2, target = data
            input1 = input1.to(device)
            input2 = input2.to(device)
            target = target.to(device)

            optimizer.zero_grad()

            # Forward pass
            output = model(input1, input2)

            # Calculate loss
            loss = criterion(output, target)

            # Backward pass and optimization
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            if i % 100 == 4:  # Print statistics every 4 batches
                print(f'[Epoch:{epoch + 1}, Batch:{i + 1:5d}] loss: {running_loss / 100:.3f}')
                running_loss = 0.0

             # Evaluation phase (after each epoch)
            model.eval()  # Set the model to evaluation mode
            with torch.no_grad():
                test_loss = 0.0
                all_predictions = []
                all_targets = []
                for input1, input2, target in test_dataloader:
                    input1 = input1.to(device)
                    input2 = input2.to(device)
                    target = target.to(device)

                    # Predict using the model
                    output = model(input1, input2)

                    # Calculate the loss
                    loss = criterion(output, target)
                    test_loss += loss.item()

                    # Store predictions and targets for MAPE calculation
                    all_predictions.append(output.cpu().numpy())
                    all_targets.append(target.cpu().numpy())

                # Calculate MAPE
                all_predictions = np.concatenate(all_predictions).flatten() # Flatten the array
                all_targets = np.concatenate(all_targets).flatten() # Flatten the array
                mape = mean_absolute_percentage_error(all_targets, all_predictions)

                # Print evaluation results
                if i % 100 == 4:  # Print statistics every 4 batches
                  print(f'[Epoch:{epoch + 1}] Test Loss: {test_loss / len(test_dataloader):.3f}, MAPE: {mape:.3f}')


# Define the training function (same as before)
# ... (code for train)



# Set paths to your input and output folders
input1_folder = '/content/drive/MyDrive/traindata/landfilll/input/EC_0.5'  # Replace with your actual path
input2_folder = '/content/drive/MyDrive/traindata/landfilll/input/thermal'  # Replace with your actual path
output_folder = '/content/drive/MyDrive/traindata/landfilll/label' # Replace with your actual path

# Define data transformations (e.g., normalization, resizing)
transform = transforms.Compose([
    transforms.Resize((480, 480)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Create the dataset
dataset = ImageDataset(input1_folder, input2_folder, output_folder, transform=transform)

# Split the dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=0.1, random_state=42)

# Create dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)  # Use batch size 1 for test


# Create the model, optimizer, and loss function
model = Model()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# Train the model
train(model, train_dataloader, test_dataloader, optimizer, criterion, epochs=500)

'''#Example usage:
model = Model()







# Input images (assume these are your 2-channel images)
image1 = torch.randn(1, 1, 480, 480)
image2 = torch.randn(1, 1, 480, 480)

# Pass images through the model
output = model(image1, image2)

# Output will have shape [1, 3, 480, 480]
print(output.shape)'''
# Out:
# [Epoch:1, Batch:    5] loss: 0.031
# [Epoch:1] Test Loss: 0.615, MAPE: 1.025
# [Epoch:2, Batch:    5] loss: 0.031
# [Epoch:2] Test Loss: 0.615, MAPE: 1.025
# [Epoch:3, Batch:    5] loss: 0.030
# [Epoch:3] Test Loss: 0.615, MAPE: 1.025
# [Epoch:4, Batch:    5] loss: 0.026
# [Epoch:4] Test Loss: 0.615, MAPE: 1.025
# [Epoch:5, Batch:    5] loss: 0.027
# [Epoch:5] Test Loss: 0.615, MAPE: 1.025
# [Epoch:6, Batch:    5] loss: 0.025
# [Epoch:6] Test Loss: 0.615, MAPE: 1.025
# [Epoch:7, Batch:    5] loss: 0.031
# [Epoch:7] Test Loss: 0.615, MAPE: 1.025
# [Epoch:8, Batch:    5] loss: 0.028
# [Epoch:8] Test Loss: 0.615, MAPE: 1.025
# [Epoch:9, Batch:    5] loss: 0.028
# [Epoch:9] Test Loss: 0.615, MAPE: 1.025
# [Epoch:10, Batch:    5] loss: 0.027
# [Epoch:10] Test Loss: 0.615, MAPE: 1.025
# [Epoch:11, Batch:    5] loss: 0.031
# [Epoch:11] Test Loss: 0.615, MAPE: 1.025
# [Epoch:12, Batch:    5] loss: 0.027
# [Epoch:12] Test Loss: 0.615, MAPE: 1.025
# [Epoch:13, Batch:    5] loss: 0.027
# [Epoch:13] Test Loss: 0.615, MAPE: 1.025
# [Epoch:14, Batch:    5] loss: 0.030
# [Epoch:14] Test Loss: 0.615, MAPE: 1.025
# [Epoch:15, Batch:    5] loss: 0.025
# [Epoch:15] Test Loss: 0.615, MAPE: 1.025
# [Epoch:16, Batch:    5] loss: 0.028
# [Epoch:16] Test Loss: 0.615, MAPE: 1.025
# [Epoch:17, Batch:    5] loss: 0.025
# [Epoch:17] Test Loss: 0.615, MAPE: 1.025
# [Epoch:18, Batch:    5] loss: 0.027
# [Epoch:18] Test Loss: 0.615, MAPE: 1.025
# [Epoch:19, Batch:    5] loss: 0.031
# [Epoch:19] Test Loss: 0.615, MAPE: 1.025
# [Epoch:20, Batch:    5] loss: 0.031
# [Epoch:20] Test Loss: 0.615, MAPE: 1.025
# [Epoch:21, Batch:    5] loss: 0.032
# [Epoch:21] Test Loss: 0.615, MAPE: 1.025
# [Epoch:22, Batch:    5] loss: 0.028
# [Epoch:22] Test Loss: 0.615, MAPE: 1.025
# [Epoch:23, Batch:    5] loss: 0.020
# [Epoch:23] Test Loss: 0.615, MAPE: 1.025
# [Epoch:24, Batch:    5] loss: 0.025
# [Epoch:24] Test Loss: 0.615, MAPE: 1.025
# [Epoch:25, Batch:    5] loss: 0.025
# [Epoch:25] Test Loss: 0.615, MAPE: 1.025
# [Epoch:26, Batch:    5] loss: 0.028
# [Epoch:26] Test Loss: 0.615, MAPE: 1.025
# [Epoch:27, Batch:    5] loss: 0.029
# [Epoch:27] Test Loss: 0.615, MAPE: 1.025
# [Epoch:28, Batch:    5] loss: 0.028
# [Epoch:28] Test Loss: 0.615, MAPE: 1.025
# [Epoch:29, Batch:    5] loss: 0.031
# [Epoch:29] Test Loss: 0.615, MAPE: 1.025
# [Epoch:30, Batch:    5] loss: 0.027
# [Epoch:30] Test Loss: 0.615, MAPE: 1.025
# [Epoch:31, Batch:    5] loss: 0.027
# [Epoch:31] Test Loss: 0.615, MAPE: 1.025
# [Epoch:32, Batch:    5] loss: 0.034
# [Epoch:32] Test Loss: 0.615, MAPE: 1.025
# [Epoch:33, Batch:    5] loss: 0.030
# [Epoch:33] Test Loss: 0.615, MAPE: 1.025
# [Epoch:34, Batch:    5] loss: 0.029
# [Epoch:34] Test Loss: 0.615, MAPE: 1.025
# [Epoch:35, Batch:    5] loss: 0.029
# [Epoch:35] Test Loss: 0.615, MAPE: 1.025
# [Epoch:36, Batch:    5] loss: 0.030
# [Epoch:36] Test Loss: 0.615, MAPE: 1.025
# [Epoch:37, Batch:    5] loss: 0.028
# [Epoch:37] Test Loss: 0.615, MAPE: 1.025
# [Epoch:38, Batch:    5] loss: 0.033
# [Epoch:38] Test Loss: 0.615, MAPE: 1.025
# [Epoch:39, Batch:    5] loss: 0.028
# [Epoch:39] Test Loss: 0.615, MAPE: 1.025
# [Epoch:40, Batch:    5] loss: 0.030
# [Epoch:40] Test Loss: 0.615, MAPE: 1.025
# [Epoch:41, Batch:    5] loss: 0.025
# [Epoch:41] Test Loss: 0.615, MAPE: 1.025
# [Epoch:42, Batch:    5] loss: 0.029
# [Epoch:42] Test Loss: 0.615, MAPE: 1.025
# [Epoch:43, Batch:    5] loss: 0.027
# [Epoch:43] Test Loss: 0.615, MAPE: 1.025
# [Epoch:44, Batch:    5] loss: 0.029
# [Epoch:44] Test Loss: 0.615, MAPE: 1.025
# [Epoch:45, Batch:    5] loss: 0.034
# [Epoch:45] Test Loss: 0.615, MAPE: 1.025
# [Epoch:46, Batch:    5] loss: 0.024
# [Epoch:46] Test Loss: 0.615, MAPE: 1.025
# [Epoch:47, Batch:    5] loss: 0.025
# [Epoch:47] Test Loss: 0.615, MAPE: 1.025
# [Epoch:48, Batch:    5] loss: 0.029
# [Epoch:48] Test Loss: 0.615, MAPE: 1.025
# [Epoch:49, Batch:    5] loss: 0.025
# [Epoch:49] Test Loss: 0.615, MAPE: 1.025
# [Epoch:50, Batch:    5] loss: 0.024
# [Epoch:50] Test Loss: 0.615, MAPE: 1.025
# [Epoch:51, Batch:    5] loss: 0.024
# [Epoch:51] Test Loss: 0.615, MAPE: 1.025
# [Epoch:52, Batch:    5] loss: 0.026
# [Epoch:52] Test Loss: 0.615, MAPE: 1.025
# [Epoch:53, Batch:    5] loss: 0.028
# [Epoch:53] Test Loss: 0.615, MAPE: 1.025
# [Epoch:54, Batch:    5] loss: 0.022
# [Epoch:54] Test Loss: 0.615, MAPE: 1.025
# [Epoch:55, Batch:    5] loss: 0.025
# [Epoch:55] Test Loss: 0.615, MAPE: 1.025
# [Epoch:56, Batch:    5] loss: 0.032
# [Epoch:56] Test Loss: 0.615, MAPE: 1.025
# [Epoch:57, Batch:    5] loss: 0.026
# [Epoch:57] Test Loss: 0.615, MAPE: 1.025
# [Epoch:58, Batch:    5] loss: 0.027
# [Epoch:58] Test Loss: 0.615, MAPE: 1.025
# [Epoch:59, Batch:    5] loss: 0.026
# [Epoch:59] Test Loss: 0.615, MAPE: 1.025
# [Epoch:60, Batch:    5] loss: 0.025
# [Epoch:60] Test Loss: 0.615, MAPE: 1.025
# [Epoch:61, Batch:    5] loss: 0.027
# [Epoch:61] Test Loss: 0.615, MAPE: 1.025
# [Epoch:62, Batch:    5] loss: 0.034
# [Epoch:62] Test Loss: 0.615, MAPE: 1.025
# [Epoch:63, Batch:    5] loss: 0.028
# [Epoch:63] Test Loss: 0.615, MAPE: 1.025
# [Epoch:64, Batch:    5] loss: 0.026
# [Epoch:64] Test Loss: 0.615, MAPE: 1.025
# [Epoch:65, Batch:    5] loss: 0.025
# [Epoch:65] Test Loss: 0.615, MAPE: 1.025
# [Epoch:66, Batch:    5] loss: 0.024
# [Epoch:66] Test Loss: 0.615, MAPE: 1.025
# [Epoch:67, Batch:    5] loss: 0.029
# [Epoch:67] Test Loss: 0.615, MAPE: 1.025
# [Epoch:68, Batch:    5] loss: 0.027
# [Epoch:68] Test Loss: 0.615, MAPE: 1.025
# [Epoch:69, Batch:    5] loss: 0.026
# [Epoch:69] Test Loss: 0.615, MAPE: 1.025
# [Epoch:70, Batch:    5] loss: 0.030
# [Epoch:70] Test Loss: 0.615, MAPE: 1.025
# [Epoch:71, Batch:    5] loss: 0.035
# [Epoch:71] Test Loss: 0.615, MAPE: 1.025
# [Epoch:72, Batch:    5] loss: 0.028
# [Epoch:72] Test Loss: 0.615, MAPE: 1.025
# [Epoch:73, Batch:    5] loss: 0.027
# [Epoch:73] Test Loss: 0.615, MAPE: 1.025
# [Epoch:74, Batch:    5] loss: 0.028
# [Epoch:74] Test Loss: 0.615, MAPE: 1.025
# [Epoch:75, Batch:    5] loss: 0.026
# [Epoch:75] Test Loss: 0.615, MAPE: 1.025
# [Epoch:76, Batch:    5] loss: 0.028
# [Epoch:76] Test Loss: 0.615, MAPE: 1.025
# [Epoch:77, Batch:    5] loss: 0.025
# [Epoch:77] Test Loss: 0.615, MAPE: 1.025
# [Epoch:78, Batch:    5] loss: 0.027
# [Epoch:78] Test Loss: 0.615, MAPE: 1.025
# [Epoch:79, Batch:    5] loss: 0.028
# [Epoch:79] Test Loss: 0.615, MAPE: 1.025
# [Epoch:80, Batch:    5] loss: 0.029
# [Epoch:80] Test Loss: 0.615, MAPE: 1.025
# [Epoch:81, Batch:    5] loss: 0.027
# [Epoch:81] Test Loss: 0.615, MAPE: 1.025
# [Epoch:82, Batch:    5] loss: 0.024
# [Epoch:82] Test Loss: 0.615, MAPE: 1.025
# [Epoch:83, Batch:    5] loss: 0.032
# [Epoch:83] Test Loss: 0.615, MAPE: 1.025
# [Epoch:84, Batch:    5] loss: 0.024
# [Epoch:84] Test Loss: 0.615, MAPE: 1.025
# [Epoch:85, Batch:    5] loss: 0.026
# [Epoch:85] Test Loss: 0.615, MAPE: 1.025
# [Epoch:86, Batch:    5] loss: 0.028
# [Epoch:86] Test Loss: 0.615, MAPE: 1.025
# [Epoch:87, Batch:    5] loss: 0.033
# [Epoch:87] Test Loss: 0.615, MAPE: 1.025
# [Epoch:88, Batch:    5] loss: 0.024
# [Epoch:88] Test Loss: 0.615, MAPE: 1.025
# [Epoch:89, Batch:    5] loss: 0.023
# [Epoch:89] Test Loss: 0.615, MAPE: 1.025
# [Epoch:90, Batch:    5] loss: 0.029
# [Epoch:90] Test Loss: 0.615, MAPE: 1.025
# [Epoch:91, Batch:    5] loss: 0.034
# [Epoch:91] Test Loss: 0.615, MAPE: 1.025
# [Epoch:92, Batch:    5] loss: 0.024
# [Epoch:92] Test Loss: 0.615, MAPE: 1.025
# [Epoch:93, Batch:    5] loss: 0.025
# [Epoch:93] Test Loss: 0.615, MAPE: 1.025
# [Epoch:94, Batch:    5] loss: 0.027
# [Epoch:94] Test Loss: 0.615, MAPE: 1.025
# [Epoch:95, Batch:    5] loss: 0.027
# [Epoch:95] Test Loss: 0.615, MAPE: 1.025
# [Epoch:96, Batch:    5] loss: 0.029
# [Epoch:96] Test Loss: 0.615, MAPE: 1.025
# [Epoch:97, Batch:    5] loss: 0.027
# [Epoch:97] Test Loss: 0.615, MAPE: 1.025
# [Epoch:98, Batch:    5] loss: 0.028
# [Epoch:98] Test Loss: 0.615, MAPE: 1.025
# [Epoch:99, Batch:    5] loss: 0.025
# [Epoch:99] Test Loss: 0.615, MAPE: 1.025
# [Epoch:100, Batch:    5] loss: 0.035
# [Epoch:100] Test Loss: 0.615, MAPE: 1.025
# [Epoch:101, Batch:    5] loss: 0.032
# [Epoch:101] Test Loss: 0.615, MAPE: 1.025
# [Epoch:102, Batch:    5] loss: 0.025
# [Epoch:102] Test Loss: 0.615, MAPE: 1.025
# [Epoch:103, Batch:    5] loss: 0.030
# [Epoch:103] Test Loss: 0.615, MAPE: 1.025
# [Epoch:104, Batch:    5] loss: 0.028
# [Epoch:104] Test Loss: 0.615, MAPE: 1.025
# [Epoch:105, Batch:    5] loss: 0.028
# [Epoch:105] Test Loss: 0.615, MAPE: 1.025
# [Epoch:106, Batch:    5] loss: 0.023
# [Epoch:106] Test Loss: 0.615, MAPE: 1.025
# [Epoch:107, Batch:    5] loss: 0.027
# [Epoch:107] Test Loss: 0.615, MAPE: 1.025
# [Epoch:108, Batch:    5] loss: 0.022
# [Epoch:108] Test Loss: 0.615, MAPE: 1.025
# [Epoch:109, Batch:    5] loss: 0.028
# [Epoch:109] Test Loss: 0.615, MAPE: 1.025
# [Epoch:110, Batch:    5] loss: 0.029
# [Epoch:110] Test Loss: 0.615, MAPE: 1.025
# [Epoch:111, Batch:    5] loss: 0.031
# [Epoch:111] Test Loss: 0.615, MAPE: 1.025
# [Epoch:112, Batch:    5] loss: 0.032
# [Epoch:112] Test Loss: 0.615, MAPE: 1.025
# [Epoch:113, Batch:    5] loss: 0.032
# [Epoch:113] Test Loss: 0.615, MAPE: 1.025
# [Epoch:114, Batch:    5] loss: 0.026
# [Epoch:114] Test Loss: 0.615, MAPE: 1.025
# [Epoch:115, Batch:    5] loss: 0.029
# [Epoch:115] Test Loss: 0.615, MAPE: 1.025
# [Epoch:116, Batch:    5] loss: 0.033
# [Epoch:116] Test Loss: 0.615, MAPE: 1.025
# [Epoch:117, Batch:    5] loss: 0.025
# [Epoch:117] Test Loss: 0.615, MAPE: 1.025
# [Epoch:118, Batch:    5] loss: 0.029
# [Epoch:118] Test Loss: 0.615, MAPE: 1.025
# [Epoch:119, Batch:    5] loss: 0.032
# [Epoch:119] Test Loss: 0.615, MAPE: 1.025
# [Epoch:120, Batch:    5] loss: 0.026
# [Epoch:120] Test Loss: 0.615, MAPE: 1.025
# [Epoch:121, Batch:    5] loss: 0.035
# [Epoch:121] Test Loss: 0.615, MAPE: 1.025
# [Epoch:122, Batch:    5] loss: 0.031
# [Epoch:122] Test Loss: 0.615, MAPE: 1.025
# [Epoch:123, Batch:    5] loss: 0.034
# [Epoch:123] Test Loss: 0.615, MAPE: 1.025
# [Epoch:124, Batch:    5] loss: 0.035
# [Epoch:124] Test Loss: 0.615, MAPE: 1.025
# [Epoch:125, Batch:    5] loss: 0.029
# [Epoch:125] Test Loss: 0.615, MAPE: 1.025
# [Epoch:126, Batch:    5] loss: 0.026
# [Epoch:126] Test Loss: 0.615, MAPE: 1.025
# [Epoch:127, Batch:    5] loss: 0.029
# [Epoch:127] Test Loss: 0.615, MAPE: 1.025
# [Epoch:128, Batch:    5] loss: 0.031
# [Epoch:128] Test Loss: 0.615, MAPE: 1.025
# [Epoch:129, Batch:    5] loss: 0.025
# [Epoch:129] Test Loss: 0.615, MAPE: 1.025
# [Epoch:130, Batch:    5] loss: 0.028
# [Epoch:130] Test Loss: 0.615, MAPE: 1.025
# [Epoch:131, Batch:    5] loss: 0.030
# [Epoch:131] Test Loss: 0.615, MAPE: 1.025
# [Epoch:132, Batch:    5] loss: 0.026
# [Epoch:132] Test Loss: 0.615, MAPE: 1.025
# [Epoch:133, Batch:    5] loss: 0.029
# [Epoch:133] Test Loss: 0.615, MAPE: 1.025
# [Epoch:134, Batch:    5] loss: 0.027
# [Epoch:134] Test Loss: 0.615, MAPE: 1.025
# [Epoch:135, Batch:    5] loss: 0.030
# [Epoch:135] Test Loss: 0.615, MAPE: 1.025
# [Epoch:136, Batch:    5] loss: 0.022
# [Epoch:136] Test Loss: 0.615, MAPE: 1.025
# [Epoch:137, Batch:    5] loss: 0.032
# [Epoch:137] Test Loss: 0.615, MAPE: 1.025
# [Epoch:138, Batch:    5] loss: 0.028
# [Epoch:138] Test Loss: 0.615, MAPE: 1.025
# [Epoch:139, Batch:    5] loss: 0.025
# [Epoch:139] Test Loss: 0.615, MAPE: 1.025
# [Epoch:140, Batch:    5] loss: 0.026
# [Epoch:140] Test Loss: 0.615, MAPE: 1.025
# [Epoch:141, Batch:    5] loss: 0.031
# [Epoch:141] Test Loss: 0.615, MAPE: 1.025
# [Epoch:142, Batch:    5] loss: 0.026
# [Epoch:142] Test Loss: 0.615, MAPE: 1.025
# [Epoch:143, Batch:    5] loss: 0.025
# [Epoch:143] Test Loss: 0.615, MAPE: 1.025
# [Epoch:144, Batch:    5] loss: 0.027
# [Epoch:144] Test Loss: 0.615, MAPE: 1.025
# [Epoch:145, Batch:    5] loss: 0.032
# [Epoch:145] Test Loss: 0.615, MAPE: 1.025
# [Epoch:146, Batch:    5] loss: 0.029
# [Epoch:146] Test Loss: 0.615, MAPE: 1.025
# [Epoch:147, Batch:    5] loss: 0.026
# [Epoch:147] Test Loss: 0.615, MAPE: 1.025
# [Epoch:148, Batch:    5] loss: 0.028
# [Epoch:148] Test Loss: 0.615, MAPE: 1.025
# [Epoch:149, Batch:    5] loss: 0.030
# [Epoch:149] Test Loss: 0.615, MAPE: 1.025
# [Epoch:150, Batch:    5] loss: 0.032
# [Epoch:150] Test Loss: 0.615, MAPE: 1.025
# [Epoch:151, Batch:    5] loss: 0.028
# [Epoch:151] Test Loss: 0.615, MAPE: 1.025
# [Epoch:152, Batch:    5] loss: 0.026
# [Epoch:152] Test Loss: 0.615, MAPE: 1.025
# [Epoch:153, Batch:    5] loss: 0.025
# [Epoch:153] Test Loss: 0.615, MAPE: 1.025
# [Epoch:154, Batch:    5] loss: 0.024
# [Epoch:154] Test Loss: 0.615, MAPE: 1.025
# [Epoch:155, Batch:    5] loss: 0.028
# [Epoch:155] Test Loss: 0.615, MAPE: 1.025
# [Epoch:156, Batch:    5] loss: 0.027
# [Epoch:156] Test Loss: 0.615, MAPE: 1.025
# [Epoch:157, Batch:    5] loss: 0.032
# [Epoch:157] Test Loss: 0.615, MAPE: 1.025
# [Epoch:158, Batch:    5] loss: 0.029
# [Epoch:158] Test Loss: 0.615, MAPE: 1.025
# [Epoch:159, Batch:    5] loss: 0.028
# [Epoch:159] Test Loss: 0.615, MAPE: 1.025
# [Epoch:160, Batch:    5] loss: 0.026
# [Epoch:160] Test Loss: 0.615, MAPE: 1.025
# [Epoch:161, Batch:    5] loss: 0.026
# [Epoch:161] Test Loss: 0.615, MAPE: 1.025
# [Epoch:162, Batch:    5] loss: 0.027
# [Epoch:162] Test Loss: 0.615, MAPE: 1.025
# [Epoch:163, Batch:    5] loss: 0.030
# [Epoch:163] Test Loss: 0.615, MAPE: 1.025
# [Epoch:164, Batch:    5] loss: 0.030
# [Epoch:164] Test Loss: 0.615, MAPE: 1.025
# [Epoch:165, Batch:    5] loss: 0.032
# [Epoch:165] Test Loss: 0.615, MAPE: 1.025
# [Epoch:166, Batch:    5] loss: 0.027
# [Epoch:166] Test Loss: 0.615, MAPE: 1.025
# [Epoch:167, Batch:    5] loss: 0.028
# [Epoch:167] Test Loss: 0.615, MAPE: 1.025
# [Epoch:168, Batch:    5] loss: 0.032
# [Epoch:168] Test Loss: 0.615, MAPE: 1.025
# [Epoch:169, Batch:    5] loss: 0.031
# [Epoch:169] Test Loss: 0.615, MAPE: 1.025
# [Epoch:170, Batch:    5] loss: 0.030
# [Epoch:170] Test Loss: 0.615, MAPE: 1.025
# [Epoch:171, Batch:    5] loss: 0.030
# [Epoch:171] Test Loss: 0.615, MAPE: 1.025
# [Epoch:172, Batch:    5] loss: 0.030
# [Epoch:172] Test Loss: 0.615, MAPE: 1.025
# [Epoch:173, Batch:    5] loss: 0.030
# [Epoch:173] Test Loss: 0.615, MAPE: 1.025
# [Epoch:174, Batch:    5] loss: 0.026
# [Epoch:174] Test Loss: 0.615, MAPE: 1.025
# [Epoch:175, Batch:    5] loss: 0.028
# [Epoch:175] Test Loss: 0.615, MAPE: 1.025
# [Epoch:176, Batch:    5] loss: 0.029
# [Epoch:176] Test Loss: 0.615, MAPE: 1.025
# [Epoch:177, Batch:    5] loss: 0.035
# [Epoch:177] Test Loss: 0.615, MAPE: 1.025
# [Epoch:178, Batch:    5] loss: 0.032
# [Epoch:178] Test Loss: 0.615, MAPE: 1.025
# [Epoch:179, Batch:    5] loss: 0.032
# [Epoch:179] Test Loss: 0.615, MAPE: 1.025
# [Epoch:180, Batch:    5] loss: 0.026
# [Epoch:180] Test Loss: 0.615, MAPE: 1.025
# [Epoch:181, Batch:    5] loss: 0.025
# [Epoch:181] Test Loss: 0.615, MAPE: 1.025
# [Epoch:182, Batch:    5] loss: 0.025
# [Epoch:182] Test Loss: 0.615, MAPE: 1.025
# [Epoch:183, Batch:    5] loss: 0.030
# [Epoch:183] Test Loss: 0.615, MAPE: 1.025
# [Epoch:184, Batch:    5] loss: 0.030
# [Epoch:184] Test Loss: 0.615, MAPE: 1.025
# [Epoch:185, Batch:    5] loss: 0.030
# [Epoch:185] Test Loss: 0.615, MAPE: 1.025
# [Epoch:186, Batch:    5] loss: 0.028
# [Epoch:186] Test Loss: 0.615, MAPE: 1.025
# [Epoch:187, Batch:    5] loss: 0.026
# [Epoch:187] Test Loss: 0.615, MAPE: 1.025
# [Epoch:188, Batch:    5] loss: 0.028
# [Epoch:188] Test Loss: 0.615, MAPE: 1.025
# [Epoch:189, Batch:    5] loss: 0.031
# [Epoch:189] Test Loss: 0.615, MAPE: 1.025
# [Epoch:190, Batch:    5] loss: 0.028
# [Epoch:190] Test Loss: 0.615, MAPE: 1.025
# [Epoch:191, Batch:    5] loss: 0.025
# [Epoch:191] Test Loss: 0.615, MAPE: 1.025
# [Epoch:192, Batch:    5] loss: 0.033
# [Epoch:192] Test Loss: 0.615, MAPE: 1.025
# [Epoch:193, Batch:    5] loss: 0.033
# [Epoch:193] Test Loss: 0.615, MAPE: 1.025
# [Epoch:194, Batch:    5] loss: 0.029
# [Epoch:194] Test Loss: 0.615, MAPE: 1.025
# [Epoch:195, Batch:    5] loss: 0.030
# [Epoch:195] Test Loss: 0.615, MAPE: 1.025
# [Epoch:196, Batch:    5] loss: 0.031
# [Epoch:196] Test Loss: 0.615, MAPE: 1.025
# [Epoch:197, Batch:    5] loss: 0.027
# [Epoch:197] Test Loss: 0.615, MAPE: 1.025
# [Epoch:198, Batch:    5] loss: 0.030
# [Epoch:198] Test Loss: 0.615, MAPE: 1.025
# [Epoch:199, Batch:    5] loss: 0.029
# [Epoch:199] Test Loss: 0.615, MAPE: 1.025
# [Epoch:200, Batch:    5] loss: 0.027
# [Epoch:200] Test Loss: 0.615, MAPE: 1.025
# [Epoch:201, Batch:    5] loss: 0.028
# [Epoch:201] Test Loss: 0.615, MAPE: 1.025
# [Epoch:202, Batch:    5] loss: 0.024
# [Epoch:202] Test Loss: 0.615, MAPE: 1.025
# [Epoch:203, Batch:    5] loss: 0.028
# [Epoch:203] Test Loss: 0.615, MAPE: 1.025
# [Epoch:204, Batch:    5] loss: 0.028
# [Epoch:204] Test Loss: 0.615, MAPE: 1.025
# [Epoch:205, Batch:    5] loss: 0.028
# [Epoch:205] Test Loss: 0.615, MAPE: 1.025
# [Epoch:206, Batch:    5] loss: 0.031
# [Epoch:206] Test Loss: 0.615, MAPE: 1.025
# [Epoch:207, Batch:    5] loss: 0.030
# [Epoch:207] Test Loss: 0.615, MAPE: 1.025
# [Epoch:208, Batch:    5] loss: 0.030
# [Epoch:208] Test Loss: 0.615, MAPE: 1.025
# [Epoch:209, Batch:    5] loss: 0.029
# [Epoch:209] Test Loss: 0.615, MAPE: 1.025
# [Epoch:210, Batch:    5] loss: 0.030
# [Epoch:210] Test Loss: 0.615, MAPE: 1.025
# [Epoch:211, Batch:    5] loss: 0.020
# [Epoch:211] Test Loss: 0.615, MAPE: 1.025
# [Epoch:212, Batch:    5] loss: 0.029
# [Epoch:212] Test Loss: 0.615, MAPE: 1.025
# [Epoch:213, Batch:    5] loss: 0.028
# [Epoch:213] Test Loss: 0.615, MAPE: 1.025
# [Epoch:214, Batch:    5] loss: 0.025
# [Epoch:214] Test Loss: 0.615, MAPE: 1.025
# [Epoch:215, Batch:    5] loss: 0.027
# [Epoch:215] Test Loss: 0.615, MAPE: 1.025
# [Epoch:216, Batch:    5] loss: 0.025
# [Epoch:216] Test Loss: 0.615, MAPE: 1.025
# [Epoch:217, Batch:    5] loss: 0.026
# [Epoch:217] Test Loss: 0.615, MAPE: 1.025
# [Epoch:218, Batch:    5] loss: 0.026
# [Epoch:218] Test Loss: 0.615, MAPE: 1.025
# [Epoch:219, Batch:    5] loss: 0.025
# [Epoch:219] Test Loss: 0.615, MAPE: 1.025
# [Epoch:220, Batch:    5] loss: 0.030
# [Epoch:220] Test Loss: 0.615, MAPE: 1.025
# [Epoch:221, Batch:    5] loss: 0.032
# [Epoch:221] Test Loss: 0.615, MAPE: 1.025
# [Epoch:222, Batch:    5] loss: 0.031
# [Epoch:222] Test Loss: 0.615, MAPE: 1.025
# [Epoch:223, Batch:    5] loss: 0.027
# [Epoch:223] Test Loss: 0.615, MAPE: 1.025
# [Epoch:224, Batch:    5] loss: 0.022
# [Epoch:224] Test Loss: 0.615, MAPE: 1.025
# [Epoch:225, Batch:    5] loss: 0.026
# [Epoch:225] Test Loss: 0.615, MAPE: 1.025
# [Epoch:226, Batch:    5] loss: 0.031
# [Epoch:226] Test Loss: 0.615, MAPE: 1.025
# [Epoch:227, Batch:    5] loss: 0.030
# [Epoch:227] Test Loss: 0.615, MAPE: 1.025
# [Epoch:228, Batch:    5] loss: 0.028
# [Epoch:228] Test Loss: 0.615, MAPE: 1.025
# [Epoch:229, Batch:    5] loss: 0.029
# [Epoch:229] Test Loss: 0.615, MAPE: 1.025
# [Epoch:230, Batch:    5] loss: 0.029
# [Epoch:230] Test Loss: 0.615, MAPE: 1.025
# [Epoch:231, Batch:    5] loss: 0.028
# [Epoch:231] Test Loss: 0.615, MAPE: 1.025
# [Epoch:232, Batch:    5] loss: 0.029
# [Epoch:232] Test Loss: 0.615, MAPE: 1.025
# [Epoch:233, Batch:    5] loss: 0.030
# [Epoch:233] Test Loss: 0.615, MAPE: 1.025
# [Epoch:234, Batch:    5] loss: 0.032
# [Epoch:234] Test Loss: 0.615, MAPE: 1.025
# [Epoch:235, Batch:    5] loss: 0.027
# [Epoch:235] Test Loss: 0.615, MAPE: 1.025
# [Epoch:236, Batch:    5] loss: 0.023
# [Epoch:236] Test Loss: 0.615, MAPE: 1.025
# [Epoch:237, Batch:    5] loss: 0.028
# [Epoch:237] Test Loss: 0.615, MAPE: 1.025
# [Epoch:238, Batch:    5] loss: 0.027
# [Epoch:238] Test Loss: 0.615, MAPE: 1.025
# [Epoch:239, Batch:    5] loss: 0.030
# [Epoch:239] Test Loss: 0.615, MAPE: 1.025
# [Epoch:240, Batch:    5] loss: 0.030
# [Epoch:240] Test Loss: 0.615, MAPE: 1.025
# [Epoch:241, Batch:    5] loss: 0.030
# [Epoch:241] Test Loss: 0.615, MAPE: 1.025
# [Epoch:242, Batch:    5] loss: 0.029
# [Epoch:242] Test Loss: 0.615, MAPE: 1.025
# [Epoch:243, Batch:    5] loss: 0.031
# [Epoch:243] Test Loss: 0.615, MAPE: 1.025
# [Epoch:244, Batch:    5] loss: 0.021
# [Epoch:244] Test Loss: 0.615, MAPE: 1.025
# [Epoch:245, Batch:    5] loss: 0.031
# [Epoch:245] Test Loss: 0.615, MAPE: 1.025
# [Epoch:246, Batch:    5] loss: 0.024
# [Epoch:246] Test Loss: 0.615, MAPE: 1.025
# [Epoch:247, Batch:    5] loss: 0.031
# [Epoch:247] Test Loss: 0.615, MAPE: 1.025
# [Epoch:248, Batch:    5] loss: 0.026
# [Epoch:248] Test Loss: 0.615, MAPE: 1.025
# [Epoch:249, Batch:    5] loss: 0.025
# [Epoch:249] Test Loss: 0.615, MAPE: 1.025
# [Epoch:250, Batch:    5] loss: 0.030
# [Epoch:250] Test Loss: 0.615, MAPE: 1.025
# [Epoch:251, Batch:    5] loss: 0.033
# [Epoch:251] Test Loss: 0.615, MAPE: 1.025
# [Epoch:252, Batch:    5] loss: 0.029
# [Epoch:252] Test Loss: 0.615, MAPE: 1.025
# [Epoch:253, Batch:    5] loss: 0.030
# [Epoch:253] Test Loss: 0.615, MAPE: 1.025
# [Epoch:254, Batch:    5] loss: 0.030
# [Epoch:254] Test Loss: 0.615, MAPE: 1.025
# [Epoch:255, Batch:    5] loss: 0.029
# [Epoch:255] Test Loss: 0.615, MAPE: 1.025
# [Epoch:256, Batch:    5] loss: 0.029
# [Epoch:256] Test Loss: 0.615, MAPE: 1.025
# [Epoch:257, Batch:    5] loss: 0.030
# [Epoch:257] Test Loss: 0.615, MAPE: 1.025
# [Epoch:258, Batch:    5] loss: 0.031
# [Epoch:258] Test Loss: 0.615, MAPE: 1.025
# [Epoch:259, Batch:    5] loss: 0.028
# [Epoch:259] Test Loss: 0.615, MAPE: 1.025
# [Epoch:260, Batch:    5] loss: 0.027
# [Epoch:260] Test Loss: 0.615, MAPE: 1.025
# [Epoch:261, Batch:    5] loss: 0.029
# [Epoch:261] Test Loss: 0.615, MAPE: 1.025
# [Epoch:262, Batch:    5] loss: 0.027
# [Epoch:262] Test Loss: 0.615, MAPE: 1.025
# [Epoch:263, Batch:    5] loss: 0.029
# [Epoch:263] Test Loss: 0.615, MAPE: 1.025
# [Epoch:264, Batch:    5] loss: 0.029
# [Epoch:264] Test Loss: 0.615, MAPE: 1.025
# [Epoch:265, Batch:    5] loss: 0.029
# [Epoch:265] Test Loss: 0.615, MAPE: 1.025
# [Epoch:266, Batch:    5] loss: 0.029
# [Epoch:266] Test Loss: 0.615, MAPE: 1.025
# [Epoch:267, Batch:    5] loss: 0.033
# [Epoch:267] Test Loss: 0.615, MAPE: 1.025
# [Epoch:268, Batch:    5] loss: 0.031
# [Epoch:268] Test Loss: 0.615, MAPE: 1.025
# [Epoch:269, Batch:    5] loss: 0.033
# [Epoch:269] Test Loss: 0.615, MAPE: 1.025
# [Epoch:270, Batch:    5] loss: 0.027
# [Epoch:270] Test Loss: 0.615, MAPE: 1.025
# [Epoch:271, Batch:    5] loss: 0.029
# [Epoch:271] Test Loss: 0.615, MAPE: 1.025
# [Epoch:272, Batch:    5] loss: 0.028
# [Epoch:272] Test Loss: 0.615, MAPE: 1.025
# [Epoch:273, Batch:    5] loss: 0.027
# [Epoch:273] Test Loss: 0.615, MAPE: 1.025
# [Epoch:274, Batch:    5] loss: 0.028
# [Epoch:274] Test Loss: 0.615, MAPE: 1.025
# [Epoch:275, Batch:    5] loss: 0.030
# [Epoch:275] Test Loss: 0.615, MAPE: 1.025
# [Epoch:276, Batch:    5] loss: 0.029
# [Epoch:276] Test Loss: 0.615, MAPE: 1.025
# [Epoch:277, Batch:    5] loss: 0.032
# [Epoch:277] Test Loss: 0.615, MAPE: 1.025
# [Epoch:278, Batch:    5] loss: 0.028
# [Epoch:278] Test Loss: 0.615, MAPE: 1.025
# [Epoch:279, Batch:    5] loss: 0.022
# [Epoch:279] Test Loss: 0.615, MAPE: 1.025
# [Epoch:280, Batch:    5] loss: 0.029
# [Epoch:280] Test Loss: 0.615, MAPE: 1.025
# [Epoch:281, Batch:    5] loss: 0.025
# [Epoch:281] Test Loss: 0.615, MAPE: 1.025
# [Epoch:282, Batch:    5] loss: 0.029
# [Epoch:282] Test Loss: 0.615, MAPE: 1.025
# [Epoch:283, Batch:    5] loss: 0.033
# [Epoch:283] Test Loss: 0.615, MAPE: 1.025
# [Epoch:284, Batch:    5] loss: 0.024
# [Epoch:284] Test Loss: 0.615, MAPE: 1.025
# [Epoch:285, Batch:    5] loss: 0.027
# [Epoch:285] Test Loss: 0.615, MAPE: 1.025
# [Epoch:286, Batch:    5] loss: 0.023
# [Epoch:286] Test Loss: 0.615, MAPE: 1.025
# [Epoch:287, Batch:    5] loss: 0.029
# [Epoch:287] Test Loss: 0.615, MAPE: 1.025
# [Epoch:288, Batch:    5] loss: 0.026
# [Epoch:288] Test Loss: 0.615, MAPE: 1.025
# [Epoch:289, Batch:    5] loss: 0.025
# [Epoch:289] Test Loss: 0.615, MAPE: 1.025
# [Epoch:290, Batch:    5] loss: 0.029
# [Epoch:290] Test Loss: 0.615, MAPE: 1.025
# [Epoch:291, Batch:    5] loss: 0.029
# [Epoch:291] Test Loss: 0.615, MAPE: 1.025
# [Epoch:292, Batch:    5] loss: 0.026
# [Epoch:292] Test Loss: 0.615, MAPE: 1.025
# [Epoch:293, Batch:    5] loss: 0.028
# [Epoch:293] Test Loss: 0.615, MAPE: 1.025
# [Epoch:294, Batch:    5] loss: 0.030
# [Epoch:294] Test Loss: 0.615, MAPE: 1.025
# [Epoch:295, Batch:    5] loss: 0.031
# [Epoch:295] Test Loss: 0.615, MAPE: 1.025
# [Epoch:296, Batch:    5] loss: 0.024
# [Epoch:296] Test Loss: 0.615, MAPE: 1.025
# [Epoch:297, Batch:    5] loss: 0.030
# [Epoch:297] Test Loss: 0.615, MAPE: 1.025
# [Epoch:298, Batch:    5] loss: 0.025
# [Epoch:298] Test Loss: 0.615, MAPE: 1.025
# [Epoch:299, Batch:    5] loss: 0.029
# [Epoch:299] Test Loss: 0.615, MAPE: 1.025
# [Epoch:300, Batch:    5] loss: 0.029
# [Epoch:300] Test Loss: 0.615, MAPE: 1.025
# [Epoch:301, Batch:    5] loss: 0.028
# [Epoch:301] Test Loss: 0.615, MAPE: 1.025
# [Epoch:302, Batch:    5] loss: 0.025
# [Epoch:302] Test Loss: 0.615, MAPE: 1.025
# [Epoch:303, Batch:    5] loss: 0.024
# [Epoch:303] Test Loss: 0.615, MAPE: 1.025
# [Epoch:304, Batch:    5] loss: 0.026
# [Epoch:304] Test Loss: 0.615, MAPE: 1.025
# [Epoch:305, Batch:    5] loss: 0.030
# [Epoch:305] Test Loss: 0.615, MAPE: 1.025
# [Epoch:306, Batch:    5] loss: 0.030
# [Epoch:306] Test Loss: 0.615, MAPE: 1.025
# [Epoch:307, Batch:    5] loss: 0.030
# [Epoch:307] Test Loss: 0.615, MAPE: 1.025
# [Epoch:308, Batch:    5] loss: 0.025
# [Epoch:308] Test Loss: 0.615, MAPE: 1.025
# [Epoch:309, Batch:    5] loss: 0.027
# [Epoch:309] Test Loss: 0.615, MAPE: 1.025
# [Epoch:310, Batch:    5] loss: 0.029
# [Epoch:310] Test Loss: 0.615, MAPE: 1.025
# [Epoch:311, Batch:    5] loss: 0.030
# [Epoch:311] Test Loss: 0.615, MAPE: 1.025
# [Epoch:312, Batch:    5] loss: 0.025
# [Epoch:312] Test Loss: 0.615, MAPE: 1.025
# [Epoch:313, Batch:    5] loss: 0.034
# [Epoch:313] Test Loss: 0.615, MAPE: 1.025
# [Epoch:314, Batch:    5] loss: 0.029
# [Epoch:314] Test Loss: 0.615, MAPE: 1.025
# [Epoch:315, Batch:    5] loss: 0.026
# [Epoch:315] Test Loss: 0.615, MAPE: 1.025
# [Epoch:316, Batch:    5] loss: 0.025
# [Epoch:316] Test Loss: 0.615, MAPE: 1.025
# [Epoch:317, Batch:    5] loss: 0.028
# [Epoch:317] Test Loss: 0.615, MAPE: 1.025
# [Epoch:318, Batch:    5] loss: 0.030
# [Epoch:318] Test Loss: 0.615, MAPE: 1.025
# [Epoch:319, Batch:    5] loss: 0.025
# [Epoch:319] Test Loss: 0.615, MAPE: 1.025
# [Epoch:320, Batch:    5] loss: 0.029
# [Epoch:320] Test Loss: 0.615, MAPE: 1.025
# [Epoch:321, Batch:    5] loss: 0.027
# [Epoch:321] Test Loss: 0.615, MAPE: 1.025
# [Epoch:322, Batch:    5] loss: 0.030
# [Epoch:322] Test Loss: 0.615, MAPE: 1.025
# [Epoch:323, Batch:    5] loss: 0.033
# [Epoch:323] Test Loss: 0.615, MAPE: 1.025
# [Epoch:324, Batch:    5] loss: 0.027
# [Epoch:324] Test Loss: 0.615, MAPE: 1.025
# [Epoch:325, Batch:    5] loss: 0.027
# [Epoch:325] Test Loss: 0.615, MAPE: 1.025
# [Epoch:326, Batch:    5] loss: 0.029
# [Epoch:326] Test Loss: 0.615, MAPE: 1.025
# [Epoch:327, Batch:    5] loss: 0.031
# [Epoch:327] Test Loss: 0.615, MAPE: 1.025
# [Epoch:328, Batch:    5] loss: 0.025
# [Epoch:328] Test Loss: 0.615, MAPE: 1.025
# [Epoch:329, Batch:    5] loss: 0.032
# [Epoch:329] Test Loss: 0.615, MAPE: 1.025
# [Epoch:330, Batch:    5] loss: 0.029
# [Epoch:330] Test Loss: 0.615, MAPE: 1.025
# [Epoch:331, Batch:    5] loss: 0.031
# [Epoch:331] Test Loss: 0.615, MAPE: 1.025
# [Epoch:332, Batch:    5] loss: 0.028
# [Epoch:332] Test Loss: 0.615, MAPE: 1.025
# [Epoch:333, Batch:    5] loss: 0.028
# [Epoch:333] Test Loss: 0.615, MAPE: 1.025
# [Epoch:334, Batch:    5] loss: 0.024
# [Epoch:334] Test Loss: 0.615, MAPE: 1.025
# [Epoch:335, Batch:    5] loss: 0.028
# [Epoch:335] Test Loss: 0.615, MAPE: 1.025
# [Epoch:336, Batch:    5] loss: 0.027
# [Epoch:336] Test Loss: 0.615, MAPE: 1.025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-36f4eef47a4a> in <cell line: 266>()
#     264
#     265 # Train the model
# --> 266 train(model, train_dataloader, test_dataloader, optimizer, criterion, epochs=500)
#     267
#     268 '''#Example usage:
#
# <ipython-input-2-36f4eef47a4a> in train(model, train_dataloader, test_dataloader, optimizer, criterion, epochs)
#     214                     # Calculate the loss
#     215                     loss = criterion(output, target)
# --> 216                     test_loss += loss.item()
#     217
#     218                     # Store predictions and targets for MAPE calculation
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
